# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/sameerjha462000/datasets/main/jamesbond.csv')

# %%
df
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
df.head(1)
# Out:
#      Film  Year         Actor       Director  Box Office  Budget  \
# 0  Dr. No  1962  Sean Connery  Terence Young       448.8     7.0
#
#    Bond Actor Salary
# 0                0.6

# %%
df.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
df.tail()
# Out:
#                  Film  Year         Actor            Director  Box Office  \
# 22      Casino Royale  2006  Daniel Craig     Martin Campbell       581.5
# 23  Quantum of Solace  2008  Daniel Craig        Marc Forster       514.2
# 24            Skyfall  2012  Daniel Craig          Sam Mendes       943.5
# 25            Spectre  2015  Daniel Craig          Sam Mendes       726.7
# 26     No Time to Die  2021  Daniel Craig  Cary Joji Fukunaga       774.2
#
#     Budget  Bond Actor Salary
# 22   145.3                3.3
# 23   181.4                8.1
# 24   170.2               14.5
# 25   206.3               30.0
# 26   301.0               25.0

# %%
df.tail(1)
# Out:
#               Film  Year         Actor            Director  Box Office  \
# 26  No Time to Die  2021  Daniel Craig  Cary Joji Fukunaga       774.2
#
#     Budget  Bond Actor Salary
# 26   301.0               25.0

# %%
x = df.tail(1)

# %%
x['Bond Actor Salary'] = 100
# Out:
# C:\Users\HU496FA\AppData\Local\Temp\ipykernel_5408\2696302966.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x['Bond Actor Salary'] = 100

# %%
x
# Out:
#               Film  Year         Actor            Director  Box Office  \
# 26  No Time to Die  2021  Daniel Craig  Cary Joji Fukunaga       774.2
#
#     Budget  Bond Actor Salary
# 26   301.0                100

# %%
df
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
# gives random row
df.sample()
# Out:
#                    Film  Year         Actor      Director  Box Office  Budget  \
# 7  Diamonds Are Forever  1971  Sean Connery  Guy Hamilton       442.5    34.7
#
#    Bond Actor Salary
# 7                5.8

# %%
df.sample()
# Out:
#                    Film  Year           Actor            Director  Box Office  \
# 19  Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode       463.2
#
#     Budget  Bond Actor Salary
# 19   133.9               10.0

# %%
y = df.sample(3)
y
# Out:
#                     Film  Year           Actor       Director  Box Office  \
# 21       Die Another Day  2002  Pierce Brosnan   Lee Tamahori       465.4
# 3            Thunderball  1965    Sean Connery  Terence Young       848.1
# 10  The Spy Who Loved Me  1977     Roger Moore  Lewis Gilbert       533.0
#
#     Budget  Bond Actor Salary
# 21   154.2               17.9
# 3     41.9                4.7
# 10    45.1                NaN

# %%
y.sample(4, replace = True)
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 10  The Spy Who Loved Me  1977   Roger Moore  Lewis Gilbert       533.0
# 10  The Spy Who Loved Me  1977   Roger Moore  Lewis Gilbert       533.0
# 10  The Spy Who Loved Me  1977   Roger Moore  Lewis Gilbert       533.0
#
#     Budget  Bond Actor Salary
# 3     41.9                4.7
# 10    45.1                NaN
# 10    45.1                NaN
# 10    45.1                NaN

# %%
y
# Out:
#                     Film  Year           Actor       Director  Box Office  \
# 21       Die Another Day  2002  Pierce Brosnan   Lee Tamahori       465.4
# 3            Thunderball  1965    Sean Connery  Terence Young       848.1
# 10  The Spy Who Loved Me  1977     Roger Moore  Lewis Gilbert       533.0
#
#     Budget  Bond Actor Salary
# 21   154.2               17.9
# 3     41.9                4.7
# 10    45.1                NaN

# %%
y['Film'] # series
# Out:
# 21         Die Another Day
# 3              Thunderball
# 10    The Spy Who Loved Me
# Name: Film, dtype: object

# %%
y
# Out:
#                     Film  Year           Actor       Director  Box Office  \
# 21       Die Another Day  2002  Pierce Brosnan   Lee Tamahori       465.4
# 3            Thunderball  1965    Sean Connery  Terence Young       848.1
# 10  The Spy Who Loved Me  1977     Roger Moore  Lewis Gilbert       533.0
#
#     Budget  Bond Actor Salary
# 21   154.2               17.9
# 3     41.9                4.7
# 10    45.1                NaN

# %%
y['Film'].loc[14]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 14
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 y['Film'].loc[14]
#
# ...

# %%
y['Film']#.iloc[1]
# Out:
# 21         Die Another Day
# 3              Thunderball
# 10    The Spy Who Loved Me
# Name: Film, dtype: object

# %%
y.iloc[1][0]
# Out:
# C:\Users\HU496FA\AppData\Local\Temp\ipykernel_5408\1892625893.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y.iloc[1][0]
# 'Thunderball'

# %%
y.loc[14]['Film']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2606, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2630, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 14
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 y.loc[14]['Film']
#
# ...

# %%
y

# %%
y.loc[14]

# %%
y.iloc[1]
# Out:
# Film                   Thunderball
# Year                          1965
# Actor                 Sean Connery
# Director             Terence Young
# Box Office                   848.1
# Budget                        41.9
# Bond Actor Salary              4.7
# Name: 3, dtype: object

# %%
y
# Out:
#                     Film  Year           Actor       Director  Box Office  \
# 21       Die Another Day  2002  Pierce Brosnan   Lee Tamahori       465.4
# 3            Thunderball  1965    Sean Connery  Terence Young       848.1
# 10  The Spy Who Loved Me  1977     Roger Moore  Lewis Gilbert       533.0
#
#     Budget  Bond Actor Salary
# 21   154.2               17.9
# 3     41.9                4.7
# 10    45.1                NaN

# %%
y.loc[[14, 17]] # fancy indexing
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 y.loc[[14, 17]]
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:1153, in _LocationIndexer.__getitem__(self, key)
#    1150 axis = self.axis or 0
#    1152 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexing.py:1382, in _LocIndexer._getitem_axis(self, key, axis)
#    1379     if hasattr(key, "ndim") and key.ndim > 1:
#    1380         raise ValueError("Cannot index with multidimensional key")
# -> 1382     return self._getitem_iterable(key, axis=axis)
#    1384 # nested tuple slicing
#    1385 if is_nested_tuple(key, labels):
#
# ...

# %%
# y.loc[14]['Film']

y.loc[(14, 'Film')]

# %%
y.loc[([14, 17], ['Film', 'Year'])]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Film               27 non-null     object
#  1   Year               27 non-null     int64
#  2   Actor              27 non-null     object
#  3   Director           27 non-null     object
#  4   Box Office         27 non-null     float64
#  5   Budget             27 non-null     float64
#  6   Bond Actor Salary  20 non-null     float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 1.6+ KB

# %%
df.describe()
# Out:
#               Year  Box Office      Budget  Bond Actor Salary
# count    27.000000   27.000000   27.000000          20.000000
# mean   1984.962963  502.077778   88.877778           8.915000
# std      17.526862  181.640790   70.227615           7.855891
# min    1962.000000  250.900000    7.000000           0.600000
# 25%    1970.000000  376.900000   39.600000           4.125000
# 50%    1983.000000  463.200000   60.200000           6.800000
# 75%    1998.000000  539.400000  139.600000          10.875000
# max    2021.000000  943.500000  301.000000          30.000000

# %%
df.describe(include = 'all')
# Out:
#                  Film         Year         Actor   Director  Box Office  \
# count              27    27.000000            27         27   27.000000
# unique             26          NaN             7         14         NaN
# top     Casino Royale          NaN  Sean Connery  John Glen         NaN
# freq                2          NaN             7          5         NaN
# mean              NaN  1984.962963           NaN        NaN  502.077778
# std               NaN    17.526862           NaN        NaN  181.640790
# min               NaN  1962.000000           NaN        NaN  250.900000
# 25%               NaN  1970.000000           NaN        NaN  376.900000
# 50%               NaN  1983.000000           NaN        NaN  463.200000
# 75%               NaN  1998.000000           NaN        NaN  539.400000
# max               NaN  2021.000000           NaN        NaN  943.500000
#
#             Budget  Bond Actor Salary
# count    27.000000          20.000000
# ...

# %%
df.sum()
# Out:
# Film                 Dr. NoFrom Russia with LoveGoldfingerThunderba...
# Year                                                             53594
# Actor                Sean ConnerySean ConnerySean ConnerySean Conne...
# Director             Terence YoungTerence YoungGuy HamiltonTerence ...
# Box Office                                                     13556.1
# Budget                                                          2399.7
# Bond Actor Salary                                                178.3
# dtype: object

# %%
df.mean(numeric_only = True)
# Out:
# Year                 1984.962963
# Box Office            502.077778
# Budget                 88.877778
# Bond Actor Salary       8.915000
# dtype: float64

# %%
df.median(numeric_only = True)
# Out:
# Year                 1983.0
# Box Office            463.2
# Budget                 60.2
# Bond Actor Salary       6.8
# dtype: float64

# %%
df.std(numeric_only = True)
# Out:
# Year                  17.526862
# Box Office           181.640790
# Budget                70.227615
# Bond Actor Salary      7.855891
# dtype: float64

# %% [markdown]
# # Masking

# %%
df.sample(5)
# Out:
#                        Film  Year           Actor            Director  \
# 20  The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 24                  Skyfall  2012    Daniel Craig          Sam Mendes
# 17          Licence to Kill  1989  Timothy Dalton           John Glen
# 19      Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 2                Goldfinger  1964    Sean Connery        Guy Hamilton
#
#     Box Office  Budget  Bond Actor Salary
# 20       439.5   158.3               13.5
# 24       943.5   170.2               14.5
# 17       250.9    56.7                7.9
# 19       463.2   133.9               10.0
# 2        820.4    18.6                3.2

# %%
df.to_string()
# Out:
# "                               Film  Year           Actor            Director  Box Office  Budget  Bond Actor Salary\n0                            Dr. No  1962    Sean Connery       Terence Young       448.8     7.0                0.6\n1             From Russia with Love  1963    Sean Connery       Terence Young       543.8    12.6                1.6\n2                        Goldfinger  1964    Sean Connery        Guy Hamilton       820.4    18.6                3.2\n3                       Thunderball  1965    Sean Connery       Terence Young       848.1    41.9                4.7\n4                     Casino Royale  1967     David Niven          Ken Hughes       315.0    85.0                NaN\n5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert       514.2    59.9                4.4\n6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt       291.5    37.3                0.6\n7              Diamonds Are Forever  1971    Sean Con
# ...

# %%
df.sample(5)
# Out:
#                     Film  Year           Actor       Director  Box Office  \
# 14             Octopussy  1983     Roger Moore      John Glen       373.8
# 10  The Spy Who Loved Me  1977     Roger Moore  Lewis Gilbert       533.0
# 23     Quantum of Solace  2008    Daniel Craig   Marc Forster       514.2
# 16  The Living Daylights  1987  Timothy Dalton      John Glen       313.5
# 12    For Your Eyes Only  1981     Roger Moore      John Glen       449.4
#
#     Budget  Bond Actor Salary
# 14    53.9                7.8
# 10    45.1                NaN
# 23   181.4                8.1
# 16    68.8                5.2
# 12    60.2                NaN

# %%
mask = (df['Director'] == 'John Glen')
df[mask]
# Out:
#                     Film  Year           Actor   Director  Box Office  Budget  \
# 12    For Your Eyes Only  1981     Roger Moore  John Glen       449.4    60.2
# 14             Octopussy  1983     Roger Moore  John Glen       373.8    53.9
# 15      A View to a Kill  1985     Roger Moore  John Glen       275.2    54.5
# 16  The Living Daylights  1987  Timothy Dalton  John Glen       313.5    68.8
# 17       Licence to Kill  1989  Timothy Dalton  John Glen       250.9    56.7
#
#     Bond Actor Salary
# 12                NaN
# 14                7.8
# 15                9.1
# 16                5.2
# 17                7.9

# %%
mask1 = df['Actor'] == 'Sean Connery'
mask2 = df['Director'] == 'Guy Hamilton'

# method 1
mask = (df['Actor'] == 'Sean Connery') & (df['Director'] == 'Guy Hamilton')

# method 2
mask = mask1 & mask2

df[mask]
# Out:
#                    Film  Year         Actor      Director  Box Office  Budget  \
# 2            Goldfinger  1964  Sean Connery  Guy Hamilton       820.4    18.6
# 7  Diamonds Are Forever  1971  Sean Connery  Guy Hamilton       442.5    34.7
#
#    Bond Actor Salary
# 2                3.2
# 7                5.8

# %%
df['Bond Actor Salary'].hasnans
# Out:
# True

# %%
df['Bond Actor Salary'].isnull().sum()
# Out:
# 7

# %%
df[df['Bond Actor Salary'].isnull()]
# Out:
#                            Film  Year         Actor        Director  \
# 4                 Casino Royale  1967   David Niven      Ken Hughes
# 8              Live and Let Die  1973   Roger Moore    Guy Hamilton
# 9   The Man with the Golden Gun  1974   Roger Moore    Guy Hamilton
# 10         The Spy Who Loved Me  1977   Roger Moore   Lewis Gilbert
# 11                    Moonraker  1979   Roger Moore   Lewis Gilbert
# 12           For Your Eyes Only  1981   Roger Moore       John Glen
# 13        Never Say Never Again  1983  Sean Connery  Irvin Kershner
#
#     Box Office  Budget  Bond Actor Salary
# 4        315.0    85.0                NaN
# 8        460.3    30.8                NaN
# 9        334.0    27.7                NaN
# 10       533.0    45.1                NaN
# 11       535.0    91.5                NaN
# 12       449.4    60.2                NaN
# 13       380.0    86.0                NaN

# %%
df
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
# it returns an iterator
x = pd.read_csv('https://raw.githubusercontent.com/sameerjha462000/datasets/main/jamesbond.csv', chunksize=9)

# %%
x

# %%
frames = [i for i in x]
# frames

# %%
type(frames)
# Out:
# list

# %%
type(frames[0])
# Out:
# pandas.core.frame.DataFrame

# %%
frames[0]
# Out:
#                               Film  Year           Actor       Director  \
# 0                           Dr. No  1962    Sean Connery  Terence Young
# 1            From Russia with Love  1963    Sean Connery  Terence Young
# 2                       Goldfinger  1964    Sean Connery   Guy Hamilton
# 3                      Thunderball  1965    Sean Connery  Terence Young
# 4                    Casino Royale  1967     David Niven     Ken Hughes
# 5              You Only Live Twice  1967    Sean Connery  Lewis Gilbert
# 6  On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# 7             Diamonds Are Forever  1971    Sean Connery   Guy Hamilton
# 8                 Live and Let Die  1973     Roger Moore   Guy Hamilton
#
#    Box Office  Budget  Bond Actor Salary
# 0       448.8     7.0                0.6
# 1       543.8    12.6                1.6
# 2       820.4    18.6                3.2
# 3       848.1    41.9                4.7
# ...

# %%
frames[1]
# Out:
#                            Film  Year           Actor        Director  \
# 9   The Man with the Golden Gun  1974     Roger Moore    Guy Hamilton
# 10         The Spy Who Loved Me  1977     Roger Moore   Lewis Gilbert
# 11                    Moonraker  1979     Roger Moore   Lewis Gilbert
# 12           For Your Eyes Only  1981     Roger Moore       John Glen
# 13        Never Say Never Again  1983    Sean Connery  Irvin Kershner
# 14                    Octopussy  1983     Roger Moore       John Glen
# 15             A View to a Kill  1985     Roger Moore       John Glen
# 16         The Living Daylights  1987  Timothy Dalton       John Glen
# 17              Licence to Kill  1989  Timothy Dalton       John Glen
#
#     Box Office  Budget  Bond Actor Salary
# 9        334.0    27.7                NaN
# 10       533.0    45.1                NaN
# 11       535.0    91.5                NaN
# 12       449.4    60.2                NaN
# 13       380.0    86.0                NaN
# ...

# %%
frames[2]
# Out:
#                        Film  Year           Actor            Director  \
# 18                GoldenEye  1995  Pierce Brosnan     Martin Campbell
# 19      Tomorrow Never Dies  1997  Pierce Brosnan  Roger Spottiswoode
# 20  The World Is Not Enough  1999  Pierce Brosnan       Michael Apted
# 21          Die Another Day  2002  Pierce Brosnan        Lee Tamahori
# 22            Casino Royale  2006    Daniel Craig     Martin Campbell
# 23        Quantum of Solace  2008    Daniel Craig        Marc Forster
# 24                  Skyfall  2012    Daniel Craig          Sam Mendes
# 25                  Spectre  2015    Daniel Craig          Sam Mendes
# 26           No Time to Die  2021    Daniel Craig  Cary Joji Fukunaga
#
#     Box Office  Budget  Bond Actor Salary
# 18       518.5    76.9                5.1
# 19       463.2   133.9               10.0
# 20       439.5   158.3               13.5
# 21       465.4   154.2               17.9
# 22       581.5   145.3                3.3
# ...

# %%
mask1 = df['Actor'] == 'Sean Connery'
df[mask1]

mask2 = df['Actor'] == 'Roger Moore'

df[mask2]

mask = mask1 | mask2

df[mask]
# Out:
#                            Film  Year         Actor        Director  \
# 0                        Dr. No  1962  Sean Connery   Terence Young
# 1         From Russia with Love  1963  Sean Connery   Terence Young
# 2                    Goldfinger  1964  Sean Connery    Guy Hamilton
# 3                   Thunderball  1965  Sean Connery   Terence Young
# 5           You Only Live Twice  1967  Sean Connery   Lewis Gilbert
# 7          Diamonds Are Forever  1971  Sean Connery    Guy Hamilton
# 8              Live and Let Die  1973   Roger Moore    Guy Hamilton
# 9   The Man with the Golden Gun  1974   Roger Moore    Guy Hamilton
# 10         The Spy Who Loved Me  1977   Roger Moore   Lewis Gilbert
# 11                    Moonraker  1979   Roger Moore   Lewis Gilbert
# 12           For Your Eyes Only  1981   Roger Moore       John Glen
# 13        Never Say Never Again  1983  Sean Connery  Irvin Kershner
# 14                    Octopussy  1983   Roger Moore       John Glen
# ...

# %%
mask = df['Actor'].isin(['Sean Connery', 'Roger Moore'])
df[mask]
# Out:
#                            Film  Year         Actor        Director  \
# 0                        Dr. No  1962  Sean Connery   Terence Young
# 1         From Russia with Love  1963  Sean Connery   Terence Young
# 2                    Goldfinger  1964  Sean Connery    Guy Hamilton
# 3                   Thunderball  1965  Sean Connery   Terence Young
# 5           You Only Live Twice  1967  Sean Connery   Lewis Gilbert
# 7          Diamonds Are Forever  1971  Sean Connery    Guy Hamilton
# 8              Live and Let Die  1973   Roger Moore    Guy Hamilton
# 9   The Man with the Golden Gun  1974   Roger Moore    Guy Hamilton
# 10         The Spy Who Loved Me  1977   Roger Moore   Lewis Gilbert
# 11                    Moonraker  1979   Roger Moore   Lewis Gilbert
# 12           For Your Eyes Only  1981   Roger Moore       John Glen
# 13        Never Say Never Again  1983  Sean Connery  Irvin Kershner
# 14                    Octopussy  1983   Roger Moore       John Glen
# ...

# %%
# df[mask].shape[0]
y = df[mask]
len(df[mask])
# Out:
# 14

# %%
# %timeit -n 10000 df[mask].shape[0]
# Out:
# 401 µs ± 14.6 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %timeit -n 10000 len(df[mask])
# Out:
# 723 µs ± 252 µs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
df
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %%
# 1. data gathering -- api, data lake, web scraping(beautifulsoup)
df
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 4                     Casino Royale  1967     David Niven          Ken Hughes
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 8                  Live and Let Die  1973     Roger Moore        Guy Hamilton
# 9       The Man with the Golden Gun  1974     Roger Moore        Guy Hamilton
# 10             The Spy Who Loved Me  1977     Roger Moore       Lewis Gilbert
# ...

# %%
# 2 data cleaning -- data inspection(head, tail, sample(5), mean(), median(), info(), describe()c, null values)
# 3 fill the null values ya fir null values waali rows ko delete krde

# %%
df.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
df.tail()
# Out:
#                  Film  Year         Actor            Director  Box Office  \
# 22      Casino Royale  2006  Daniel Craig     Martin Campbell       581.5
# 23  Quantum of Solace  2008  Daniel Craig        Marc Forster       514.2
# 24            Skyfall  2012  Daniel Craig          Sam Mendes       943.5
# 25            Spectre  2015  Daniel Craig          Sam Mendes       726.7
# 26     No Time to Die  2021  Daniel Craig  Cary Joji Fukunaga       774.2
#
#     Budget  Bond Actor Salary
# 22   145.3                3.3
# 23   181.4                8.1
# 24   170.2               14.5
# 25   206.3               30.0
# 26   301.0               25.0

# %%
df.shape
# Out:
# (27, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Film               27 non-null     object
#  1   Year               27 non-null     int64
#  2   Actor              27 non-null     object
#  3   Director           27 non-null     object
#  4   Box Office         27 non-null     float64
#  5   Budget             27 non-null     float64
#  6   Bond Actor Salary  20 non-null     float64
# dtypes: float64(3), int64(1), object(3)
# memory usage: 1.6+ KB

# %%
df.dropna(axis = 0, how = 'any')
# Out:
#                                Film  Year           Actor            Director  \
# 0                            Dr. No  1962    Sean Connery       Terence Young
# 1             From Russia with Love  1963    Sean Connery       Terence Young
# 2                        Goldfinger  1964    Sean Connery        Guy Hamilton
# 3                       Thunderball  1965    Sean Connery       Terence Young
# 5               You Only Live Twice  1967    Sean Connery       Lewis Gilbert
# 6   On Her Majesty's Secret Service  1969  George Lazenby       Peter R. Hunt
# 7              Diamonds Are Forever  1971    Sean Connery        Guy Hamilton
# 14                        Octopussy  1983     Roger Moore           John Glen
# 15                 A View to a Kill  1985     Roger Moore           John Glen
# 16             The Living Daylights  1987  Timothy Dalton           John Glen
# 17                  Licence to Kill  1989  Timothy Dalton           John Glen
# ...

# %% [markdown]
# # class 2 (19 May 2024)
#
# ## groupby object

# %%
import pandas as pd

# %%
imdb = pd.read_csv('https://raw.githubusercontent.com/sameerjha462000/datasets/main/imdb-top-1000.csv')
imdb
# Out:
#                  Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  Director              Star1  No_of_Votes        Gross  \
# ...

# %%
imdb.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Runtime', 'Genre', 'IMDB_Rating',
#        'Director', 'Star1', 'No_of_Votes', 'Gross', 'Metascore'],
#       dtype='object')

# %%
imdb.columns = imdb.columns.str.lower()

# %%
imdb
# Out:
#                  series_title released_year  runtime   genre  imdb_rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  director              star1  no_of_votes        gross  \
# ...

# %%
gbo = imdb.groupby('genre')

# %%
gbo, 
type(gbo), 
gbo.__class__.__name__
# Out:
# (<pandas.core.groupby.generic.DataFrameGroupBy object at 0x000002E4FEF393D0>,
#  pandas.core.groupby.generic.DataFrameGroupBy,
#  'DataFrameGroupBy')

# %%
imdb.head()
# Out:
#                series_title released_year  runtime   genre  imdb_rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
# 3    The Godfather: Part II          1974      202   Crime          9.0
# 4              12 Angry Men          1957       96   Crime          9.0
#
#                director           star1  no_of_votes        gross  metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %%
gbo.sum()
# Out:
#                                                 series_title  \
# genre
# Action     The Dark KnightThe Lord of the Rings: The Retu...
# Adventure  InterstellarBack to the FutureInglourious Bast...
# Animation  Sen to Chihiro no kamikakushiThe Lion KingHota...
# Biography  Schindler's ListGoodfellasHamiltonThe Intoucha...
# Comedy     GisaengchungLa vita è bellaModern TimesCity Li...
# Crime      The GodfatherThe Godfather: Part II12 Angry Me...
# Drama      The Shawshank RedemptionFight ClubForrest Gump...
# Family     E.T. the Extra-TerrestrialWilly Wonka & the Ch...
# Fantasy                Das Cabinet des Dr. CaligariNosferatu
# Film-Noir   The Third ManThe Maltese FalconShadow of a Doubt
# Horror     PsychoAlienThe ThingThe ExorcistNight of the L...
# Mystery    MementoRear WindowVertigoShutter IslandKahaani...
# Thriller                                     Wait Until Dark
# Western    Il buono, il brutto, il cattivoOnce Upon a Tim...
#
# ...

# %%
try:
    gbo.mean()
except TypeError as ex:
    print(ex)
# Out:
# agg function failed [how->mean,dtype->object]

# %%
gbo.mean(numeric_only = True)
# Out:
#               runtime  imdb_rating    no_of_votes         gross  metascore
# genre
# Action     129.046512     7.949419  420246.581395  1.897224e+08  73.419580
# Adventure  134.111111     7.937500  313557.819444  1.319017e+08  78.437500
# Animation   99.585366     7.930488  268032.073171  1.784326e+08  81.093333
# Biography  136.022727     7.938636  272805.045455  9.404952e+07  76.240506
# Comedy     112.129032     7.901290  178195.658065  1.010572e+08  78.720000
# Crime      126.392523     8.016822  313398.271028  7.899656e+07  77.080460
# Drama      124.737024     7.957439  212343.612457  1.225259e+08  79.701245
# Family     107.500000     7.800000  275610.500000  2.195553e+08  79.000000
# Fantasy     85.000000     8.000000   73111.000000  3.913633e+08        NaN
# Film-Noir  104.000000     7.966667  122405.000000  4.197018e+07  95.666667
# Horror     102.090909     7.909091  340232.363636  9.405902e+07  80.000000
# ...

# %%
imdb.head(1)
# Out:
#                series_title released_year  runtime  genre  imdb_rating  \
# 0  The Shawshank Redemption          1994      142  Drama          9.3
#
#          director        star1  no_of_votes       gross  metascore
# 0  Frank Darabont  Tim Robbins      2343110  28341469.0       80.0

# %%
# %timeit -n 100 gbo.sum()['no_of_votes']
gbo.sum()['no_of_votes']
# Out:
# 5.34 ms ± 1.19 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit -n 100 gbo['no_of_votes'].sum()
gbo['no_of_votes'].sum()
# Out:
# 484 µs ± 222 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
gbo['series_title'].count()
# Out:
# genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# Name: series_title, dtype: int64

# %% [markdown]
# # first(), last(), random(), describe(), sample(), get_group()

# %%
gbo.first()
# Out:
#                               series_title released_year  runtime  \
# genre
# Action                     The Dark Knight          2008      152
# Adventure                     Interstellar          2014      169
# Animation    Sen to Chihiro no kamikakushi          2001      125
# Biography                 Schindler's List          1993      195
# Comedy                        Gisaengchung          2019      132
# Crime                        The Godfather          1972      175
# Drama             The Shawshank Redemption          1994      142
# Family          E.T. the Extra-Terrestrial          1982      115
# Fantasy       Das Cabinet des Dr. Caligari          1920       76
# Film-Noir                    The Third Man          1949      104
# Horror                              Psycho          1960      109
# Mystery                            Memento          2000      113
# Thriller                   Wait Until Dark          1967      108
# ...

# %%
gbo.last()
# Out:
#                                   series_title released_year  runtime  \
# genre
# Action                    Escape from Alcatraz          1979      112
# Adventure                       Kelly's Heroes          1970      144
# Animation                      The Jungle Book          1967       78
# Biography                     Midnight Express          1978      121
# Comedy                  Breakfast at Tiffany's          1961      115
# Crime                             The 39 Steps          1935       86
# Drama                                 Lifeboat          1944       97
# Family     Willy Wonka & the Chocolate Factory          1971      100
# Fantasy                              Nosferatu          1922       94
# Film-Noir                    Shadow of a Doubt          1943      108
# Horror                              The Others          2001      101
# Mystery                           Lost Highway          1997      134
# ...

# %%
gbo.sample()
# Out:
#                             series_title released_year  runtime      genre  \
# 768                  Lucky Number Slevin          2006      110     Action
# 191     The Treasure of the Sierra Madre          1948      126  Adventure
# 956                                Mulan          1998       88  Animation
# 338                   The Imitation Game          2014      114  Biography
# 835             The Purple Rose of Cairo          1985       82     Comedy
# 556                 Strangers on a Train          1951      101      Crime
# 407               Der Himmel über Berlin          1987      128      Drama
# 698  Willy Wonka & the Chocolate Factory          1971      100     Family
# 321         Das Cabinet des Dr. Caligari          1920       76    Fantasy
# 712                    Shadow of a Doubt          1943      108  Film-Noir
# 844                            Halloween          1978       91     Horror
# ...

# %%
try:
    gbo.sample(2)
except ValueError as ve:
    print(ve)
# Out:
# Cannot take a larger sample than population when 'replace=False'

# %%
gbo.size()
# Out:
# genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# dtype: int64

# %%
gbo.sample(2, replace = True)
# Out:
#                             series_title released_year  runtime      genre  \
# 569                        The Gentlemen          2019      113     Action
# 275                         Blade Runner          1982      117     Action
# 604                     Captain Phillips          2013      134  Adventure
# 797           O Brother, Where Art Thou?          2000      107  Adventure
# 596                          Toy Story 4          2019      100  Animation
# 23         Sen to Chihiro no kamikakushi          2001      125  Animation
# 342                    Bohemian Rhapsody          2018      134  Biography
# 673                                Glory          1989      122  Biography
# 969                   Dazed and Confused          1993      102     Comedy
# 526              Crimes and Misdemeanors          1989      104     Comedy
# 520                         True Romance          1993      119      Crime
# ...

# %%
len(gbo)
# Out:
# 14

# %%
# without group by waali approach
imdb['genre'].value_counts()

imdb.groupby('genre').size()
# Out:
# genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# dtype: int64

# %%
gbo.describe()
# Out:
#           runtime                                                              \
#             count        mean        std    min     25%    50%     75%    max
# genre
# Action      172.0  129.046512  28.500706   45.0  110.75  127.5  143.25  321.0
# Adventure    72.0  134.111111  33.317320   88.0  109.00  127.0  149.00  228.0
# Animation    82.0   99.585366  14.530471   71.0   90.00   99.5  106.75  137.0
# Biography    88.0  136.022727  25.514466   93.0  120.00  129.0  146.25  209.0
# Comedy      155.0  112.129032  22.946213   68.0   96.00  106.0  124.50  188.0
# Crime       107.0  126.392523  27.689231   80.0  106.50  122.0  141.50  229.0
# Drama       289.0  124.737024  27.740490   64.0  105.00  121.0  137.00  242.0
# Family        2.0  107.500000  10.606602  100.0  103.75  107.5  111.25  115.0
# Fantasy       2.0   85.000000  12.727922   76.0   80.50   85.0   89.50   94.0
# Film-Noir     3.0  104.000000   4.000000  100.0  102.00  104.0  106.00  108.0
# ...

# %%
gbo.nunique()
# Out:
#            series_title  released_year  runtime  imdb_rating  director  star1  \
# genre
# Action              172             61       78           15       123    121
# Adventure            72             49       58           10        59     59
# Animation            82             35       41           11        51     77
# Biography            88             44       56           13        76     72
# Comedy              155             72       70           11       113    133
# Crime               106             56       65           14        86     85
# Drama               289             83       95           14       211    250
# Family                2              2        2            1         2      2
# Fantasy               2              2        2            2         2      2
# Film-Noir             3              3        3            3         3      3
# Horror               11             11       10            8        10     11
# ...

# %%
gbo.get_group('Western')
# Out:
#                         series_title released_year  runtime    genre  \
# 12   Il buono, il brutto, il cattivo          1966      161  Western
# 48      Once Upon a Time in the West          1968      165  Western
# 115       Per qualche dollaro in più          1965      132  Western
# 691           The Outlaw Josey Wales          1976      135  Western
#
#      imdb_rating        director           star1  no_of_votes       gross  \
# 12           8.8    Sergio Leone  Clint Eastwood       688390   6100000.0
# 48           8.5    Sergio Leone     Henry Fonda       302844   5321508.0
# 115          8.3    Sergio Leone  Clint Eastwood       232772  15000000.0
# 691          7.8  Clint Eastwood  Clint Eastwood        65659  31800000.0
#
#      metascore
# 12        90.0
# 48        80.0
# 115       74.0
# 691       69.0

# %%
gbo.get_group('Action')
# Out:
#                                           series_title released_year  runtime  \
# 2                                      The Dark Knight          2008      152
# 5        The Lord of the Rings: The Return of the King          2003      201
# 8                                            Inception          2010      148
# 10   The Lord of the Rings: The Fellowship of the Ring          2001      178
# 13               The Lord of the Rings: The Two Towers          2002      179
# ..                                                 ...           ...      ...
# 968                                       Falling Down          1993      113
# 979                                      Lethal Weapon          1987      109
# 982                                          Mad Max 2          1981       96
# 983                                       The Warriors          1979       92
# 985                               Escape from Alcatraz          1979      112
#
# ...

# %%
type(gbo.groups)#['Action'])
# Out:
# pandas.io.formats.printing.PrettyDict

# %%
print(gbo.groups)
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %%
import pprint

# %%
printer = pprint.PrettyPrinter(indent = 4)

# %%
printer.pprint(gbo.groups)
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134, 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262, 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390, 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582, 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209, 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498, 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781, 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70, 101, 135, 146, 151, 158, 170, 197, 205, 211, 213, 219, 229, 230, 242, 245, 246, 270, 
# ...

# %%
# !pip install rich

# %%
from rich import print

# %%
print(gbo.groups)
# Out:
# {'Action': [2, 5, 8, 10, 13, 14, 16, 29, 30, 31, 39, 42, 44, 55, 57, 59, 60, 63, 68, 72, 106, 109, 129, 130, 134,
# 140, 142, 144, 152, 155, 160, 161, 166, 168, 171, 172, 177, 181, 194, 201, 202, 216, 217, 223, 224, 236, 241, 262,
# 275, 294, 308, 320, 325, 326, 331, 337, 339, 340, 343, 345, 348, 351, 353, 356, 357, 362, 368, 369, 375, 376, 390,
# 410, 431, 436, 473, 477, 479, 482, 488, 493, 496, 502, 507, 511, 532, 535, 540, 543, 564, 569, 570, 573, 577, 582,
# 583, 602, 605, 608, 615, 623, ...], 'Adventure': [21, 47, 93, 110, 114, 116, 118, 137, 178, 179, 191, 193, 209,
# 226, 231, 247, 267, 273, 281, 300, 301, 304, 306, 323, 329, 361, 366, 377, 402, 406, 415, 426, 458, 470, 497, 498,
# 506, 513, 514, 537, 549, 552, 553, 566, 576, 604, 609, 618, 638, 647, 675, 681, 686, 692, 711, 713, 739, 755, 781,
# 797, 798, 851, 873, 884, 912, 919, 947, 957, 964, 966, 984, 991], 'Animation': [23, 43, 46, 56, 58, 61, 66, 70,
# ...

# %%
import json

# %%
# print(json.dumps(gbo.groups, sort_keys=True, indent = 4))
{key:list(value) for key,value in dict(gbo.groups)}
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[74], line 2
#       1 # print(json.dumps(gbo.groups, sort_keys=True, indent = 4))
# ----> 2 {key:list(value) for key,value in dict(gbo.groups)}
#
# Cell In[74], line 2, in <dictcomp>(.0)
#       1 # print(json.dumps(gbo.groups, sort_keys=True, indent = 4))
# ----> 2 {key:list(value) for key,value in dict(gbo.groups)}
#
# ValueError: too many values to unpack (expected 2)

# %%
json.dumps(gbo.groups, sort_keys=True, indent = 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 json.dumps(gbo.groups, sort_keys=True, indent = 4)
#
# File ~\AppData\Local\anaconda3\Lib\json\__init__.py:238, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
#     234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
# --> 238     **kw).encode(obj)
#
# File ~\AppData\Local\anaconda3\Lib\json\encoder.py:202, in JSONEncoder.encode(self, o)
#     200 chunks = self.iterencode(o, _one_shot=True)
#     201 if not isinstance(chunks, (list, tuple)):
# --> 202     chunks = list(chunks)
# ...

# %%
json.dumps({key: list(value) for key, value in gbo.groups.items()}, sort_index = True, indent = 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[83], line 1
# ----> 1 json.dumps({key: list(value) for key, value in gbo.groups.items()}, sort_index = True, indent = 4)
#
# File ~\AppData\Local\anaconda3\Lib\json\__init__.py:234, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
# --> 234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
#     238     **kw).encode(obj)
#
# TypeError: JSONEncoder.__init__() got an unexpected keyword argument 'sort_index'

# %%
print(json.dumps({key: list(value) for key, value in dict(gbo.groups).items()}, sort_keys = True, indent = 1))
# Out:
# {
#  "Action": [
#   2,
#   5,
#   8,
#   10,
#   13,
#   14,
#   16,
#   29,
#   30,
#   31,
#   39,
#   42,
#   44,
#   55,
#   57,
#   59,
#   60,
#   63,
#   68,
#   72,
#   106,
#   109,
#   129,
#   130,
#   134,
#   140,
#   142,
#   144,
#   152,
#   155,
#   160,
#   161,
#   166,
#   168,
#   171,
#   172,
#   177,
#   181,
#   194,
#   201,
#   202,
#   216,
#   217,
#   223,
#   224,
#   236,
#   241,
#   262,
#   275,
#   294,
#   308,
#   320,
#   325,
#   326,
#   331,
#   337,
#   339,
#   340,
#   343,
#   345,
#   348,
#   351,
#   353,
#   356,
#   357,
#   362,
#   368,
#   369,
#   375,
#   376,
#   390,
#   410,
#   431,
#   436,
#   473,
#   477,
#   479,
#   482,
#   488,
#   493,
#   496,
#   502,
#   507,
#   511,
#   532,
#   535,
#   540,
#   543,
#   564,
#   569,
#   570,
#   573,
#   577,
#   582,
#   583,
#   602,
#   605,
#   608,
#   615,
#   623,
#   625,
#   627,
#   634,
#   641,
#   642,
#   645,
#   648,
#   655,
#   659,
#   663,
#   666,
# ...

# %%
gbo

# %%
imdb
# Out:
#                  series_title released_year  runtime   genre  imdb_rating  \
# 0    The Shawshank Redemption          1994      142   Drama          9.3
# 1               The Godfather          1972      175   Crime          9.2
# 2             The Dark Knight          2008      152  Action          9.0
# 3      The Godfather: Part II          1974      202   Crime          9.0
# 4                12 Angry Men          1957       96   Crime          9.0
# ..                        ...           ...      ...     ...          ...
# 995    Breakfast at Tiffany's          1961      115  Comedy          7.6
# 996                     Giant          1956      201   Drama          7.6
# 997     From Here to Eternity          1953      118   Drama          7.6
# 998                  Lifeboat          1944       97   Drama          7.6
# 999              The 39 Steps          1935       86   Crime          7.6
#
#                  director              star1  no_of_votes        gross  \
# ...

# %%
drama_max_imdb_rating = gbo['imdb_rating'].max().loc['Drama']
drama_max_imdb_rating
# Out:
# 9.3

# %%
# find top 3 genres whose runtime is highest

# %%
imdb.head(1)
# Out:
#                series_title released_year  runtime  genre  imdb_rating  \
# 0  The Shawshank Redemption          1994      142  Drama          9.3
#
#          director        star1  no_of_votes       gross  metascore
# 0  Frank Darabont  Tim Robbins      2343110  28341469.0       80.0

# %%
gbo['runtime'].max().sort_values(ascending = False).head(3).index.to_list()
# Out:
# ['Action', 'Drama', 'Crime']

# %%
gbo['runtime'].mean().sort_values(ascending = False).head(3).index.to_list()
# Out:
# ['Western', 'Biography', 'Adventure']

# %%
worst_genre = gbo['imdb_rating'].mean().sort_values().head(1).index.to_list()[0]
worst_genre
# Out:
# 'Family'

# %%
gbo.size().head().plot(kind = 'pie', autopct = '%0.1f%%') # axis axes
None
